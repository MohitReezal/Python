# %% [markdown]
# <a href="https://colab.research.google.com/github/MohitReezal/Python/blob/main/Scatter_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bc8ed4930aa7> in <cell line: 2>()
#       1 #Plot scatter simple function
# ----> 2 x= np.linspace(-10,10,50)
#       3 y= 10*x+ 3+ np.random.randint(0,300,50)
#       4 y
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Plot scatter simple function
x= np.linspace(-10,10,50)
y= 10*x+ 3+ np.random.randint(0,300,50)
y
# Out:
# array([ 1.44000000e+02,  1.39081633e+02,  7.91632653e+01, -7.77551020e+01,
#         7.43265306e+01,  5.64081633e+01,  1.44489796e+02,  5.25714286e+01,
#         9.86530612e+01,  1.01734694e+02,  2.41816327e+02,  1.94897959e+02,
#         2.59795918e+01,  1.53061224e+02,  1.42857143e-01, -9.77551020e+00,
#         1.17306122e+02,  2.45387755e+02,  1.82469388e+02,  2.71551020e+02,
#         2.41632653e+02,  9.77142857e+01,  2.27795918e+02,  4.68775510e+01,
#         9.95918367e+00,  7.10408163e+01,  2.13122449e+02,  1.37204082e+02,
#         1.79285714e+02,  1.07367347e+02,  2.37448980e+02,  1.22530612e+02,
#         2.02612245e+02,  7.06938776e+01,  1.70775510e+02,  3.43857143e+02,
#         8.39387755e+01,  2.41020408e+02,  1.91102041e+02,  1.59183673e+02,
#         2.19265306e+02,  1.57346939e+02,  2.99428571e+02,  3.52510204e+02,
#         2.85591837e+02,  3.07673469e+02,  3.59755102e+02,  1.12836735e+02,
#         2.89918367e+02,  3.82000000e+02])

# %%
plt.scatter(x,y)

# %%
#plt.scatter on pandas data(IPL real data)
df= pd.read_csv('/content/batter.csv')
df=df.head(50)

# %%
plt.scatter(df['avg'], df['strike_rate'])
plt.title('Avg and SR analysis of Top 50 batsmen')
plt.xlabel('Average')
plt.ylabel('SR')
# Out:
# Text(0, 0.5, 'SR')

# %%
#size
tips= sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips= sns.load_dataset('tips')
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*15)

# %%
#scatterplot using plt.plot
plt.plot(tips['total_bill'],tips['tip'])
