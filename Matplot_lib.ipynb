# %% [markdown]
# <a href="https://colab.research.google.com/github/MohitReezal/Python/blob/main/Matplot_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MOhit")
# Out:
# MOhit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#plotting a simple function
price=[48000,54000,57000,45000,40000]
year= [2015,2016,2017,2018,2019]
plt.plot(year,price)

# %%
#From a pandas dataframe
batsman= pd.read_csv('/content/sharma-kohli.csv')
batsman
plt.plot(batsman['index'],batsman['V Kohli'])
